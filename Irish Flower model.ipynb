# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
# %matplotlib inline

# %%
data = pd.read_csv("IRIS.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print(data["species"].value_counts())
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
data.shape
# Out:
# (150, 5)

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(10,11))
sns.heatmap(data.corr(), annot=True)
plt.plot()
# Out:
# []

# %%
data.plot(kind = "scatter", x="petal_length", y = "petal_width")
plt.show()

# %%
data.plot(kind = "scatter", x = "sepal_length", y = "sepal_width")
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data, hue = "species", height = 4)\
.map(plt.scatter, x = "sepal_length",y =  "sepal_width")\
.add_legend();
plt.show();

# %%
data.groupby("species").count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %%
data.plot(kind = "box", sharex = False, sharey = False)

# %%
data.hist(edgecolor = "black", linewidth = 1.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000A8D03213C8>,
# ...
#       dtype=object)

# %%
data.boxplot(by="species", figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000A8D0347FD0>,
# ...
#       dtype=object)

# %%
sns.pairplot(data, hue = "species", diag_kind = "kde")
# Out:
# C:\Users\User_Pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Importing metrics for classification

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
#Separating the data into dependent and independent variables

# %%
X = data.iloc[:, :-1].values
y =data.iloc[:, -1].values

# %%
#Splitting the dataset into training and test data

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
model = [Naive Bayes, K-nearest Neighbours, Logistic Regression, Decision trees,Random Forest Classifier(n_estimators = 5, random_state = 0), SVC ]
model_names = ["Gaussian Naive Bayes", "K-nearest neighbours", "Logistic Regression", "Decision Tree Classifier", "Random Forest", "Support vector classifier"]
for i in range(0,6):
    y_pred = model[i].fit(X_train, y_train).predict(X_test)
    accuracy = accuracy_score(y_pred, y_test) * 100
    print(model_names[i], ":", accuracy, "%")
# Out:
#   File "<ipython-input-35-b22a4203b063>", line 1
#     model = [Naive Bayes, K-nearest Neighbours, Logistic Regression, Decision trees,Random Forest Classifier(n_estimators = 5, random_state = 0), SVC ]
#                        ^
# SyntaxError: invalid syntax

# %%
#Using logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
#Summary of the prediction made by the classifier

# %%
print(classification_report(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#     avg / total       0.97      0.97      0.97        30

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]

# %%
#Accuracy of score

# %%
from sklearn.metrics import accuracy_score
print("accuracy is", accuracy_score(y_test, y_pred))
# Out:
# accuracy is 0.9666666666666667
